# %%
import os
import time
import collections
import sklearn.model_selection
import gensim
import numpy as np
import tensorflow as tf
from sklearn.svm import OneClassSVM
#from utils import trans_gensim_word2vec2tf_embedding,trans_data2tf_data,trans_tokenize_data2tf_data,trans_multi_input_tokenize_data2npa
#from model_multi_textcnn import build_model
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import pickle
from scipy.stats import pearsonr
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
#from bayes_opt.bayesian_optimization import BayesianOptimization
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection.univariate_selection import f_regression
# %matplotlib inline
import warnings
import joblib
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 
warnings.filterwarnings("ignore")
# Out:
# /home/zourui/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.feature_selection.univariate_selection module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
import json
import os
import re
import collections
import numpy as np
import pandas as pd
import tensorflow as tf
import LAC
import happybase
import joblib

# %%
df_list = []
with open("/mnt/d/zourui/predict_user_attribute20201214/user_attribute20201231/user_profile/position_data") as f:
    for line in f:
        df_list.append(line.strip().split('\001'))
df = pd.DataFrame(df_list)

# %%
df
# Out:
#             0                                               1       2       3  \
# 0           1                                             CTO  380021  379528
# 1       10073                                  专业人员（工程师、设计师等）  349684  349389
# 2       10113                               董事长/总裁/CEO/董事/合伙人  378020  378036
# 3       10140                                              其他  381349  381108
# 4      101966                               董事长/总裁/CEO/董事/合伙人  381295  381108
# ...       ...                                             ...     ...     ...
# 13129   92106                                              其他  380768  380727
# 13130   93648                                              个人  381369  381411
# 13131   95954                                              运营  374274  373823
# 13132   97037                                             合伙人  364501  373305
# 13133   98706  Coder -&amp;gt; Programmer -&amp;gt; Developer  363108  363154
#
#             4       5       6       7       8       9      10      11
# 0      380043  380126  379521  379529  379451  379526  378915  379489
# 1      349248  349729  347400  349431  349650  349540  349572  348987
# 2      377965  377980  378047  378021  377903  377873  378033  378025
# 3      381299  381252  380842  381326  379187  381311  381059  380919
# 4      381284  381313  381106  380842  381316  381279  381315  381310
# ...       ...     ...     ...     ...     ...     ...     ...     ...
# 13129  380481  375323  379814  380669  380484  379839  380482  381027
# 13130  381424  381338  381299  381425  381554  381393  381309  381280
# 13131  373982  373774  374270  374217  373884  374259  373955  374257
# 13132  372948  373553  373574  373512  373551  373497  373480  373603
# 13133  363094  363024  363136  363088  358476  360535  363142  363102
#
# [13134 rows x 12 columns]

# %%
all_set = set([v.lower() for v in df[1]])
all_set
# Out:
# {'consulting',
#  '创办人兼ceo',
#  '兵',
#  '理财顾问',
#  '华南副总经理',
#  '房产总监',
#  '质检员',
#  '咸鱼干',
#  '文化创意产业管理',
#  '出口业务',
#  '物业',
#  '用户体验设计师',
#  '创业格子ceo',
#  '产品汪',
#  '职业ypr',
#  '咖啡师',
#  '资深编辑',
#  '品牌总监',
#  '新闻学子',
#  '地产经纪人',
#  '诗人',
#  '研发',
#  'accountant',
#  '软件开发工程师',
#  '哈哈哈哈哈哈哈',
#  '自媒体商务bd',
#  '没啥意思。',
#  '你说',
#  '项目总监',
#  '啥都做',
#  '经理人',
#  '投资总监',
#  '传媒经济咨询',
#  '员工',
#  '副总编辑',
#  '互联网创业者',
#  '插科打诨中',
#  '投资顾问',
#  '英语教师',
#  '合同工',
#  '置业顾问',
#  '品牌经理',
#  '修电脑的',
#  '医学生',
#  '职员',
#  '少先队员',
#  'fbi',
#  '医生，中医',
#  '内容编辑',
#  '业务总监 精英理财师',
#  '智能创新中心',
#  '白酒',
#  '爱做梦',
#  '( ㊖ ˍ ㊖ )',
#  '秃头仔',
#  '总裁兼cgo',
#  '电商o2o项目福建省销售总监',
#  '产品总监的徒弟',
#  '渠道',
#  '家装，家政，服务',
#  '设计',
#  '安静的美男子',
#  '自己做主',
#  '科教',
#  '新运营',
#  'partime manager',
#  '市场pr',
#  '产业咨询、战略咨询',
#  'designer',
#  '商业评论人',
#  '保险经纪人',
#  '建筑匠',
#  '投融资专员',
#  '智能驾驶工程师',
#  '悟道',
#  'tmt投资',
#  '销售er',
#  '金牌销售',
#  '渠道农民工',
#  '航空攻城狮',
#  '这里应该有份职业',
#  '人性研究员！',
#  '康复运动',
#  '凤凰娱乐主管',
#  'bug测试',
#  '职业情感',
#  '信贷岗',
#  '管理者',
#  '互联网运营大妈一枚',
#  '普洱茶厂家',
#  '科幻网文作者，骑行爱好者！',
#  '想做好厨子的医生',
#  '业务员',
#  'iop',
#  '工程技术',
#  '打i',
#  '高级咨询师',
#  'it工程师',
#  '行政管理',
#  '主笔，编委，高级编辑',
#  '领头攻城狮',
#  '首席策略官',
#  '中国儿童成长教育研究会研究员',
#  '前端开发工程师',
#  '高级ui设计师',
#  '金融服务',
#  '人工智能知适应系统+专业真人老师辅导',
#  '导师',
#  '董事总经理',
#  '零售',
#  '天使投资 区块链',
#  '推荐算法工程师',
#  '单创企业家俱乐部理事',
#  '网络剑客',
#  '零售供应链订货管理总监',
#  '关于美及美好',
#  '无',
#  '居家',
#  '就一个做动画的',
#  '自由建筑者',
#  '不务正业',
#  '乖孩子',
#  'raddiwallah',
#  '军师',
#  '职业耕耘者',
#  '坐家',
#  '解决方案架构师',
#  '还学习一下',
#  '高级理赔师',
#  '自由写作者',
#  '品牌策划主管',
#  '啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊',
#  '金融证券中心',
#  '在读学生',
#  '无业游民',
#  '打工',
#  '一二三四五六七八九十一二一二三四五六七八九十一二一一一二三五',
#  'seller',
#  '基础设施工程师',
#  '企业服务',
#  '企业创始人',
#  'it从业人员',
#  '拓展',
#  '区域市场从业者',
#  '无名学者',
#  '资深搬砖大师',
#  '前咨询顾问，企业战略',
#  '物流',
#  '呆着',
#  '造梦师',
#  '排雷手',
#  '捡破烂',
#  '抗压小分队',
#  'tmt记者',
#  '球员',
#  '紅酒',
#  'coo（首席运营官）',
#  '策划编辑',
#  '产品专员',
#  '财务分析师',
#  '互联网猎头，专做技术岗。',
#  '兼职',
#  '业务线总经理',
#  '投资分析师',
#  '编程人员',
#  '尚在学习',
#  '测试员',
#  '杀猪',
#  '研究僧',
#  '人力资源',
#  '营销人',
#  '影视发行',
#  '服装',
#  '创始合伙人',
#  '法师lv1',
#  '售前解决方案工程师',
#  'pm项目管理',
#  '网警',
#  '保险代理人',
#  '区域',
#  '网络媒体人',
#  'self-employed',
#  'investment',
#  '游戏运营',
#  '帮助他人',
#  '幻想家',
#  '通信男',
#  '技术人员',
#  '无脑黑',
#  '三无人员',
#  '质检',
#  '干活',
#  '首席战略顾问',
#  '变电设计',
#  '副教授',
#  '法人',
#  '来pk图噜噜噜噜啊数据库噜噜噜具体拒绝具体噜噜噜噜噜噜噜噜噜',
#  'aa',
#  '啊谁是谁的谁到底反反复复反反复复吃吃吃吃吃吃vvcccccc',
#  '研究人员',
#  '通信，消费电子，手机',
#  '侦察兵',
#  'coder -&amp;gt; programmer -&amp;gt; developer',
#  '平台经营',
#  '屌丝it男',
#  '自由自在',
#  '建筑设计',
#  '研发经理',
#  '职业鉴宝师',
#  '回血上岸',
#  '理想主义者',
#  '电子商务',
#  '攻城狮',
#  '艺术总监',
#  'supervisor of service products',
#  '项目负责人',
#  '准程序员',
#  '一个小书童',
#  '摆渡人',
#  '运营（intern）',
#  '供应链',
#  '企业员i',
#  '游走券商边缘，被互联网的潮水打湿',
#  '运营副总监',
#  '投资者',
#  '技术开发。',
#  '反洗钱主管',
#  '总经理',
#  '1#2#3#',
#  '物质超时空转移',
#  '旅宿业者',
#  '房地产相关',
#  '懒宅学生',
#  'cv工程师',
#  '第三方物流',
#  '软件码农',
#  '中西文化交流',
#  '自由撰稿人',
#  'manager',
#  '普通群众',
#  '笔记本不恐怖',
#  '内容营销经理',
#  '搬砖工',
#  '球探',
#  '用户体验分析',
#  '工作室',
#  '医务工作',
#  '盟主',
#  '道路工程师',
#  '海外并购专家、国际油气实务专家',
#  '业务讨饭一员',
#  '哈喽',
#  '企业法人',
#  '能源',
#  '设计师/设计团队负责人',
#  '我是主人翁',
#  'hrm&成长中的pm',
#  '外发跟单主管',
#  'overseas sales manager',
#  '退休',
#  '吃瓜达人',
#  '学生',
#  '民工。',
#  '猎头顾问',
#  '创新业务部总经理',
#  'ui设计师',
#  '深度互联网创业者',
#  '市场研究员',
#  'cco',
#  '科技数码自媒体',
#  '职场小白',
#  '创业分析师',
#  '前端架构师&特许金融分析师',
#  'bp',
#  '这里的职业静悄悄',
#  '电商新手',
#  '\\',
#  '金融工程师',
#  '市场开发',
#  '互联网通讯',
#  '蓝狐',
#  '自由财经编辑',
#  '活动策划',
#  '游戏人生',
#  '平面设计师',
#  '职业养猪人',
#  'pr经理',
#  '中餐行政總廚',
#  '财务',
#  '天猫运营主管',
#  '产品研发顾问',
#  'hr',
#  '挖掘机',
#  '制作平台，简称做台',
#  '策略',
#  '影视传媒从业者',
#  's&m deputy gm',
#  '金融小民工',
#  '无业',
#  '广告经理人',
#  '咨询、活动策划与执行。',
#  '企业管理顾问',
#  '阿创',
#  '算法开发工程师',
#  '对外贸易',
#  '专业卖广告',
#  '二级市场研究员',
#  '商务顾问',
#  '装饰画框类外贸业务员',
#  '人力资源，市场调研',
#  '涂料及涂装',
#  '你',
#  '互联网猎头',
#  '视频后期导演',
#  '关公',
#  '兰芝12!这：',
#  '修补大飞机',
#  '偷大米的',
#  '天眼',
#  '自负盈亏打工者',
#  '幼儿园校车司机',
#  '地产投资拓展',
#  '社群组织',
#  '软件开发',
#  '研发工程师',
#  '交互设计专家',
#  '医疗服务',
#  '旅行定制师',
#  '建筑学',
#  '哈哈哈哈high哈哈哈哈high',
#  '╇薇:404312226】幸运飞艇实力信誉代理平台',
#  '學生',
#  '寻梦找北',
#  '劲旅网副总裁',
#  '汽车',
#  '旗袍爱好者',
#  '金融行业',
#  '金融教育',
#  'researcher',
#  '互联网软件',
#  '写手',
#  'gg',
#  '医疗器械工程师',
#  '培训讲师',
#  '金融从业者',
#  '产品与业务',
#  'cto兼coo',
#  '技术型划水',
#  '内容总监',
#  '剪辑师',
#  '互联网科技',
#  '互联网从业人员',
#  '环保',
#  '保险',
#  'se',
#  '通信',
#  '公眾政治會',
#  '工人阶级',
#  '刑事律师',
#  '技术爱好者',
#  '差人',
#  '外贸部经理',
#  '自由责业者',
#  '创始人&ceo',
#  'test',
#  '执行总经理',
#  '精准广告界文盲',
#  '灯饰维修员',
#  '品牌公关',
#  '自由自在，有业无职',
#  '副总裁',
#  '市场人',
#  'cb',
#  '职业农民！农民工！',
#  '大数据工程师',
#  '社工',
#  '程序员/it技术',
#  '看热闹',
#  '商业',
#  'marketing',
#  '老白兔',
#  '鸭',
#  '媒介负责人',
#  '共鸣ok嘻嘻住户050新红米锥心ok您移民咯哦可以可以咯咯咯',
#  '新媒体主编',
#  '财经媒体',
#  '互联网行业法律人',
#  '医生',
#  '融资业务',
#  '成品油零售行业从业者',
#  '跨界实践精英',
#  '食品科学检测与安全营养',
#  '专业珠宝买手',
#  '建筑业+软件开发',
#  'od',
#  '经理',
#  '高级技术总监',
#  '品牌',
#  '材料人',
#  '0工资的职位',
#  '营销咨询',
#  '在校学生',
#  '制作人',
#  '餐饮开发',
#  '未婚',
#  '早期投资人',
#  '其他',
#  'tmt投资人',
#  '游戏',
#  '供应链管理',
#  '人口统计',
#  '品牌設計',
#  '职业炒股',
#  '铁路',
#  '集成电子',
#  '负责人',
#  '社会观察',
#  '摄影师 设计师',
#  '阅读者',
#  '111111111111111111111111111111',
#  '啊哈',
#  '人事行政',
#  '设计圈大佬',
#  'web前端交互设计',
#  '寿险规划顾问',
#  '城乡规划',
#  '测',
#  '为你服务',
#  '儿科',
#  'financial consultant',
#  '数据科学家',
#  '喵了个咪',
#  'ai',
#  '电商主管',
#  '制造业',
#  '策划管理',
#  '手工业',
#  'management consultant',
#  '赚钱',
#  '桥梁设计',
#  '艺术设计',
#  '编剧',
#  'fashion',
#  '你猜？',
#  '社会工作者',
#  '单位鸿骏膳食扛工',
#  '干将、莫邪ceo，原双乾支付法人。',
#  '好汉',
#  '高三狗',
#  'vice president',
#  '园丁',
#  '个人',
#  '拒绝了',
#  '产品工程师/技术支持',
#  '信息流',
#  '会计',
#  '精英',
#  '数字文娱投资',
#  '量化交易程序员',
#  '心理咨询师',
#  '无土种植蔬菜',
#  '客户专员',
#  'an ordinary college student',
#  'ic工程师',
#  '高级咨询顾问',
#  '城市总经理',
#  '底层劳动者',
#  '手机app开发',
#  '视频ip创意孵化',
#  '餐饮人',
#  '建筑设计师',
#  '美容',
#  '电话18033086327',
#  '人',
#  '设计爱好者',
#  '土建工程师',
#  '隐居者',
#  '售前与售后技术支持',
#  '咸鱼上班族',
#  '首席顾问',
#  '电子工程师',
#  '国家有突出贡献专家，一级导演',
#  '自由职业，诗人',
#  '采购总监',
#  '法律',
#  '品牌经营',
#  '包租公',
#  '计算机视觉',
#  '玫瑰园物业经理',
#  '拣货员',
#  '搬砖',
#  '卖房子的',
#  '资深吃货',
#  '芸芸众生',
#  'ftgccgch',
#  '运营统筹',
#  '招商经理',
#  '品牌…',
#  '背锅经理',
#  '产品岗',
#  '技术主管',
#  '奋斗者',
#  'b',
#  'life amateur.',
#  '微信运营',
#  '互动装置，多媒体展厅',
#  'builders',
#  '患得患失几乎是军事基地九十年代经济的亟待解决的家',
#  'me',
#  '商业地产投资人',
#  '铸币师',
#  'strategy',
#  '手机电子产品销售',
#  '创办人',
#  '运输',
#  '编导',
#  '私营企业主',
#  'erp实施顾问',
#  '政策顾问',
#  '忘了',
#  '业余评论员',
#  '主编',
#  '产品狗',
#  '资深媒介策划',
#  '关注互联网＋内容的音乐极客',
#  '大外大四狗',
#  'fae',
#  '企业会员',
#  '电子电路绘画员',
#  '市场分析师',
#  '市场营销在读学生',
#  'chief apology officer',
#  '战略研究',
#  '工装室内外设计师',
#  '金融分析师',
#  '聯合創始人',
#  '闲人',
#  '原咨询顾问，现某厂员工.',
#  '创始人兼ceo',
#  '投资分析师助理',
#  '以电为动力，以线为纽带，引导光明。',
#  '供应部经理',
#  '生物医药',
#  'research analyst intern',
#  '测试',
#  '莫文蔚',
#  '海外运营',
#  '互联网行业',
#  '待业',
#  '监察大队',
#  '教务总监',
#  '风投',
#  '程序员，it教育者',
#  'executive director',
#  '执行总裁',
#  '行业经理',
#  '设计行业内的非设计师',
#  '高级java软件工程师',
#  '投资分析',
#  '体制内',
#  '督导检核岗',
#  '网络运营经理',
#  '首席编辑',
#  'marketer',
#  '哈哈哈哈噜啦啦噜啦啦啦啦啦啦',
#  '店长',
#  '1',
#  '企业主',
#  '主人',
#  '外贸公司总经理',
#  'mss',
#  '管道工',
#  '互联网人的在线大学',
#  '艺术教育',
#  'yacht charters',
#  '创始人/ceo',
#  '自由职业者，也就是无业',
#  '房地产开发与管理研究生',
#  '33娘（手动滑稽）',
#  '战略管理咨询师',
#  '一般上班族',
#  '小规模奋斗者',
#  'cxo',
#  '眼镜人',
#  '外贸总监',
#  '交互设计师',
#  '码农，种植业',
#  '无业游民一枚',
#  '背锅侠、填坑王',
#  '市场策划',
#  '数据价值发现者',
#  '非著名人口',
#  '网络优化',
#  '返朴编辑部编辑主管',
#  '财务规划师和投资人',
#  '自由职业选手',
#  '培训管理',
#  '影视公司',
#  '投资',
#  '展会运营',
#  '法师',
#  'co-owner',
#  'o2o电商',
#  '营销运营总监',
#  '微生物发酵员',
#  '信托经理',
#  '移动开发工程师',
#  '固定职业',
#  '法律从业者',
#  '自媒体人（欢迎联系）',
#  '演讲教练',
#  '专业打狗师',
#  '商业创新咨询、培训；商业畅销书作者',
#  '平台产品运营',
#  'ooc',
#  '咨询公司，创投圈，linkedin等平台专栏作者',
#  'ios开发，产品经理',
#  '学习',
#  '教育培训/咨询',
#  '护士',
#  '求其',
#  'account',
#  'xx',
#  'studend',
#  '银行从业人员',
#  '财务会计',
#  '崩爆花的',
#  '#',
#  '档口运营',
#  '绿化管理',
#  '芯片',
#  '时评',
#  'running',
#  '.',
#  '国家机密',
#  '大boss',
#  '不上不下，中层',
#  '旅游体验式',
#  '电商内容',
#  '无业。',
#  'php你好',
#  '造价师',
#  'doctor',
#  '投资人，技术总监',
#  '商业策划师',
#  '物资',
#  '文化/娱乐/传媒',
#  '媒体从业人员',
#  '合伙人',
#  '黑客',
#  '算法工程师',
#  '电商从业者',
#  '首席搬砖官',
#  'ui实习设计师',
#  '市场营销',
#  '火箭总设计师',
#  '开发工程师',
#  '市场销售',
#  '养老从业者',
#  '加里敦',
#  '公务员',
#  '投融资',
#  '自主创业',
#  'po',
#  '出境旅游',
#  '123',
#  '作者',
#  '哈',
#  '咨询经理',
#  '政企dict经理',
#  '投资人 董事总经理',
#  '上医',
#  '打杂工',
#  'unknown',
#  '123456789012345678901234567890',
#  '投资部',
#  '影视后期',
#  '高级市场经理',
#  '行路人',
#  '私募基金',
#  '铁道工',
#  'mkt',
#  '观察者',
#  '战略分析',
#  '造价',
#  '零售经理',
#  '痴心',
#  '外勤',
#  '主播：74960',
#  '螺丝工',
#  '研究总监',
#  '区域经理',
#  '战略/投资',
#  '专栏作家 影评人',
#  '美丽，哦',
#  '华北停电断水大学大三苦学生一个',
#  '发起人，整合者，服务生',
#  'business solutions',
#  '通讯',
#  '媒体人',
#  '文创',
#  '公司三把手',
#  '整合营销副总监',
#  '教育地产 地产教育',
#  '调研咨询',
#  '歌手',
#  '全职',
#  '猪',
#  '资深财富规划师',
#  '英雄召唤师',
#  'events',
#  'tmt analyst',
#  '网络部经理',
#  '创业疯子',
#  '总统',
#  '自由作家',
#  '数字ic设计工程师',
#  '设计 产品',
#  '互联网产品人',
#  '租赁业务产品负责人',
#  '废物再生利用资深工程师',
#  '现实的梦想家',
#  '服务生',
#  '迟早把问题想明白了',
#  'o2o专员',
#  '产品经理',
#  '互联网运营经理',
#  '药师',
#  'hrbp',
#  '广告文案',
#  '新项目经理',
#  '摄影，摄像自媒体',
#  '策划',
#  '寿险规划师',
#  '画图的',
#  '李老昧',
#  '搬砖和泥扛大包背黑锅打群架单挑',
#  '黑社会',
#  '快消品开发',
#  '计划运营',
#  '堂主',
#  '农民工',
#  '开发',
#  '产业分析师',
#  '动画师',
#  '探险',
#  '市场推广',
#  '跑堂儿',
#  '软件测试',
#  '医院小会计',
#  '文案编剧',
#  'observer',
#  'ph.d in finance',
#  '安卓工程师',
#  'writer',
#  '军人',
#  '新闻',
#  '法律民工',
#  '医疗官',
#  '从业',
#  '大中华区运营经理',
#  '维修电工',
#  '线上营销',
#  '五金配送',
#  '职业经理人',
#  '自媒体达人',
#  '自由职业 混吃等死',
#  '个体民营',
#  '团队之友',
#  'apm',
#  '大数据开发',
#  'yingya26点com',
#  '城市发行经理',
#  '品牌公关总监',
#  '产品策划',
#  '瑜伽老师',
#  '大学党',
#  '股权融资部实习生',
#  '…',
#  '广告/数字营销',
#  '部门主任',
#  '法学院',
#  'cio（首席信息官）',
#  '网络维护',
#  '培训',
#  '皮肤性病科医生',
#  '运营老狗',
#  '副ceo',
#  'vc',
#  '数据科学',
#  '。',
#  '執行董事',
#  '分析员',
#  '投行',
#  '独立第三方',
#  '一线i',
#  '保洁',
#  '三把扫帚调酒师',
#  '法学生',
#  '创业',
#  '市场部',
#  '知识工作者',
#  '职业法师',
#  'dev',
#  'bai中国投资十年，致力于寻找和成就未来商业领袖',
#  '传道授业解惑',
#  '规划师/研究员',
#  '新媒体人，市场，品牌战略',
#  '自由职业者',
#  '不入流的总经理',
#  '天猫运营',
#  '不靠谱的生活家',
#  '职业经纪人',
#  '技术管理',
#  '媒体总监',
#  '终生荣誉学生',
#  '互联网教育运营',
#  'buyer',
#  'biz.',
#  'sale',
#  '%*%',
#  'programmer',
#  '物联网、互联网、共享项目',
#  '给',
#  '垂钓行业',
#  '收破烂',
#  '金融投资',
#  '吃瓜',
#  'engineer',
#  '码字员',
#  '律师',
#  '服务行业',
#  '为祖国的花朵服务',
#  '数据分析',
#  '警察',
#  'c',
#  '市场及品牌主管',
#  '萝莉控',
#  '内容生产者也',
#  '招生官',
#  '互联网教育 互联网文娱',
#  '业余摄影爱好者',
#  '融资担保',
#  '职业也不好',
#  '中台运营',
#  '晚上3大道4额我头疼的热热4呃呃呃若额3t3啊哦111111',
#  '文化创意',
#  '赔率分析师',
#  '逐风者',
#  '副总经理',
#  '策划执行总监',
#  '新媒体从业者',
#  '广告',
#  '市场部总经理',
#  '私募基金 电影投资',
#  '混混',
#  '营销策划',
#  '市场经理',
#  '高校教师',
#  '医疗',
#  '工程师 自由职业者 业余交易者',
#  '投资人/媒体人',
#  '就不告诉你',
#  '经济分析师',
#  '水军',
#  '文案',
#  '合规',
#  '原猫扑网运营总监、360手机粉丝运营总监、酷我音乐产品总监',
#  'llllllkkjftcfcfcrcrcrcrctctvtv',
#  '掌门人',
#  '厨师',
#  '教育行业实干者',
#  '董事长助理',
#  '摄影人',
#  '前途未卜的会计狗',
#  '。。。',
#  '西部计划志愿者',
#  '渠道管理',
#  'tuer',
#  '从业者',
#  '杂工',
#  '网络自由职业',
#  '空间通信工程师',
#  '销售工程师',
#  '无祂',
#  '正',
#  '自由+苦力',
#  'tddx',
#  '淘宝店主',
#  '解甲归田',
#  '管理咨询师',
#  '园艺',
#  '伏虎者',
#  'it经理',
#  '厉害',
#  '打杂总监',
#  '返乡创业者',
#  '前瞻思维',
#  '医',
#  '主要负责人',
#  '企划部pm',
#  '运营狮',
#  '公共关系负责人',
#  '品牌宣传',
#  'a',
#  '投机倒把',
#  '部门经理助理',
#  '硬件工程师',
#  '研究咨询',
#  '消费类电子行业',
#  '金融从业人员',
#  'ggg',
#  '老板娘',
#  '公司推广员',
#  '想当专业喷子结果发现不会骂人',
#  'assurance',
#  '主理人',
#  'hrd',
#  '小会计',
#  'aaaas@the aaa!!dfksdghjkjjytdd',
#  '新媒体运营',
#  '灵魂渡者',
#  '信息流广告优化师',
#  '海外高端房产管理',
#  '招商从业人员',
#  '备研中',
#  '莫得',
#  'okay',
#  '人力资源管理',
#  '游民',
#  '互联网营销管理',
#  '学人',
#  '信用审批',
#  '集成电路后端',
#  '互联网基层民工',
#  '管理培训生',
#  'broker',
#  '战略投资管理中心副总经理',
#  '管理岗',
#  '学渣渣',
#  '工程项目管理',
#  '程序猿',
#  '研究经理',
#  '建材行业',
#  '1111',
#  'office365，巨硬全家桶技术支持',
#  '资深开发工程师',
#  '安全喵',
#  '在读',
#  '为了实现美好的愿望努力奋斗',
#  'vp',
#  '游玩',
#  '管理员',
#  '中医按摩师',
#  '被人吐槽不牛逼',
#  '咸鱼',
#  '供应链负责人',
#  '金融信托理财',
#  '财务不自由的自由人',
#  '设计总监',
#  '通信业',
#  '职业奶爸',
#  '不分贵贱',
#  '需求分析师',
#  '汽车设计师',
#  '老总',
#  '规划师',
#  '精准医学',
#  '捷税官',
#  '美食家',
#  'youyu',
#  '互联网编辑',
#  'java工程师',
#  '产品项目经理',
#  'seo',
#  '架构师/解决方案专家/it成本专家',
#  '职业撰稿人',
#  '互联网运营',
#  '产品助理',
#  '品牌“间谍”',
#  '市场情报',
#  '成份分析师',
#  '弱电工程',
#  '市场总监助理（品牌方向）',
#  '机构自媒体',
#  '创意人',
#  '假记者',
#  '应该要有选择',
#  '风险管理',
#  '专治不服高级咨询师',
#  '助理',
#  '高级数据分析师',
#  '随时要换',
#  '商业化实现高级项目经理',
#  '房地产',
#  '金融民工',
#  'pmo',
#  '清洁',
#  '写字楼租赁顾问',
#  '管理会计',
#  ...}

# %%
#企业创始人/CEO
ceo_set = set()
ceo_pattern = re.compile('|'.join(map(re.escape, ["董事长","总裁","ceo","董事","合伙人","总经理","副总经理","老板"])),flags=re.IGNORECASE)

# %%
#企业业务决策层
decision_level_set = set()
decision_level_pattern = re.compile('|'.join(map(re.escape, ['cio', 'cfo', 'coo', 'cto', 'cko', 'cpo', 'cgo', 'cmo', 'cso',"首席","行长","投资经理"])),flags=re.IGNORECASE)

# %%
#企业一般管理人员
manager_set = set()
manager_pattern = re.compile('|'.join(map(re.escape, ["总监","主管","总助","负责人","中层干部"])),flags=re.IGNORECASE)

# %%
# 事业单位员工
public_institution_set = set()
public_institution_pattern = re.compile('|'.join(map(re.escape, ["公务员","主任","教务","老师","教师","列车","政府","常委","教師","人民公仆","院长","医","驻华大使"])),flags=re.IGNORECASE)

# %%
# 高校学生
student_set = set()
student_pattern = re.compile('|'.join(map(re.escape, ["二战","大专","高三","大四","大一","大二","大一","学生","研究生","博士","大学","应届生","本科","硕士","博士"])),flags=re.IGNORECASE)

# %%
# 其他（自由职业）
other_set = set()
other_pattern = re.compile('|'.join(map(re.escape, ["自由","啥都干","流民","浪人"])),flags=re.IGNORECASE)

# %%
#企业普通员工
staff_set = set()
staff_pattern =  re.compile('|'.join(map(re.escape, ["工程师","民工","分析师","设计师","苦力","编程","员工","工人","架构师",
   "清洁","经理助理","客户经理","项目经理","从业者","规划师","部经理","公务员","销售经理"])),flags=re.IGNORECASE)

# %%
#这里有bug已解决
for v in all_set:
    if list(re.finditer(ceo_pattern,v)):
        ceo_set.add(v)
    elif list(re.finditer(decision_level_pattern,v)):
        decision_level_set.add(v)
    elif list(re.finditer(manager_pattern,v)):
        manager_set.add(v)
    elif list(re.finditer(public_institution_pattern,v)):
        public_institution_set.add(v)
    elif list(re.finditer(student_pattern,v)):
        student_set.add(v)
    elif list(re.finditer(staff_pattern,v)):
        staff_set.add(v)
    else:
        if list(re.finditer(other_pattern,v)) or len(v) > 10:
            other_set.add(v)
        else:
            staff_set.add(v)

# %%
all_set = all_set - ceo_set - decision_level_set - manager_set - staff_set - public_institution_set - student_set - other_set
print(len(all_set))
# Out:
# 0

# %%
print(len(ceo_set))
print(ceo_set)
print(len(decision_level_set))
print(decision_level_set)
print(len(manager_set))
print(manager_set)
print(len(public_institution_set))
print(public_institution_set)
print(len(student_set))
print(student_set)
print(len(other_set))
print(other_set)
print(len(staff_set))
print(staff_set)
# Out:
# 69
# {'投资人 董事总经理', '非总裁', '产品经理，创业者，老板', '老板', '创办人兼ceo', 'ceo/董事/合伙人', '劲旅网副总裁', '业务线总经理', '常务副总裁', '品牌公关，营销传播，ceo-pr', '华南副总经理', '董事长助理', '董事长', '执行合伙人', '总经理，导演，视频设计师', '董事长兼ceo', 'ceo', '总经理助理', '高级合伙人', '老板娘', '梵溪花園品牌ceo', '销售总经理', '创始合伙人', '执行总裁', '渔你同行ceo', '创业格子ceo', '合伙人', '不入流的总经理', '城市总经理', '总裁兼cgo', '未来总经理', '执行董事', '创业者@合伙人', '副总经理', '吉家集团全国发展副总经理', '北方区总经理', '董事长兼司机', '律所合伙人', '创始人&ceo', '助理总裁', '创新业务部总经理', 'ceo与创始人', '执行总经理', '副总 & 合伙人', '董事总经理', '基金合伙人', '市场部总经理', '高级副总裁 数字化转型顾问 区块链创新', '小老板', '投资银行部 助理董事', '外贸公司总经理', '总经理', '创始人兼ceo', '高级副总裁', '创始人暨ceo', '首席执行官兼总经理', '创始ceo', '总裁', '副ceo', '战略投资管理中心副总经理', '公司创办人/ceo', '干将、莫邪ceo，原双乾支付法人。', '创始人/ceo', '总经理/副总经理', '副总经理兼coo', '董事长秘书', '董事长/总裁/ceo/董事/合伙人', '執行董事', '副总裁'}
# 31
aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa', '自由职业 混吃等死', '啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊啊', '想当专业喷子结果发现不会骂人', '自由职业选手', 'english tutor', 's&m deputy gm', '服务业，果蔬商贸与酒店管理', '咨询、活动策划与执行。', 'aaaas@the aaa!!dfksdghjkjjytdd', 'yingya26点com', '自由媒体人', '测试kkk图听哦你好哦请知悉体系替我狗韩 拉锯具体看信', '他他他他他他他他他他他他他他他他他他他他他他他他他他他', '一二三四五六七八九十一二一二三四五六七八九十一二一一一二三五', 'credit analyst', 'software engineer', '自由职业者。', '在公司除了挣钱的事，其他什么都干', '独特的异途同归公共机构股份和f肌肤持久哥哥哥哥哥哥哥哥哥哥', '只是对互联网感兴趣罢了', '电话18033086327', 'technical manager', '澳门永利娱乐--www.7112.com', '做啥不重要，生存和生活，都得先活下去', '想成为很厉害的产品经理', '商业创新咨询、培训；商业畅销书作者', '外商投资及收并购咨询顾问', '战略投资、战略规划、资源整合', '民航界混日 ...
# 2055
# {'consulting', '兵', '理财顾问', '质检员', '咸鱼干', '文化创意产业管理', '出口业务', '物业', '用户体验设计师', '产品汪', '职业ypr', '咖啡师', '资深编辑', '新闻学子', '地产经纪人', '诗人', 'accountant', '研发', '软件开发工程师', '哈哈哈哈哈哈哈', '自媒体商务bd', '没啥意思。', '你说', '啥都做', '经理人', '传媒经济咨询', '员工', '副总编辑', '互联网创业者', '插科打诨中', '投资顾问', '合同工', '置业顾问', '品牌经理', '修电脑的', '职员', '少先队员', 'fbi', '内容编辑', '智能创新中心', '白酒', '爱做梦', '( ㊖ ˍ ㊖ )', '秃头仔', '渠道', '家装，家政，服务', '设计', '安静的美男子', '自己做主', '科教', '新运营', '市场pr', '产业咨询、战略咨询', 'designer', '商业评论人', '保险经纪人', '建筑匠', '投融资专员', '智能驾驶工程师', '悟道', 'tmt投资', '销售er', '金牌销售', '渠道农民工', '航空攻城狮', '这里应该有份职业', '人性研究员！', '康复运动', 'bug测试', '职业情感', '信贷岗', '管理者', '互联网运营大妈一枚', '普洱茶厂家', '业务员', 'iop', '工程技术', '打i', '高级咨询师', 'it工程师', '行政管理', '主笔，编委，高级编辑', '领头攻城狮', '前端开发工程师', '高级ui设计师', '金融服务', '导师', '零售', '天使投资 区块链', '推荐算法工程师', '单创企业家俱乐部理事', '网络剑客', '关于美及美好', '无', '居家', '就一个做动画的', '不务正业', '乖孩子', '军师', '职业耕耘者', '坐家', '解决方案架构师', '还学习一下', '高级理赔师', '金融证券中心', '无业游民', '打工', 'seller', '基础设施工程师', '企业服务', '企业创始人', 'it从业人员', '拓展', '区域市场从业者', '无名学者', '资深搬砖大师', '前咨询顾问，企业战略', '物流', '呆着', '造梦师', '排雷手', '捡破烂', '抗压小分队', 'tmt记者', '球员', '紅酒', '策划编辑', '产品专员', '财务分析师', '兼职', '投资分析师', '编程人员', '尚在学习', '测试员', '杀猪', '研究�
理', '手工业', '赚钱', '桥梁设计', '艺术设计', '编剧', 'fashion', '你猜？', '社会工作者', '单位鸿骏膳食扛工', '好汉', '园丁', '个人', '拒绝了', '产品工程师/技术支持', '信息流', '会计', '精英', '数字文娱投资', '量化交易程序员', '心理咨询师', '无土种植蔬菜', '客户专员', 'ic工程师', '高级咨询顾问', '底层劳动者', '手机app开发', '视频ip创意孵化', '餐饮人', '建筑设计师', '美容', '人', '设计爱好者', '土建工程师', '隐居者', '售前与售后技术支持', '咸鱼上班族', '电子工程师', '法律', '品牌经营', '包租公', '计算机视觉', '玫瑰园物业经理', '拣货员', '搬砖', '卖房子的', '资深吃货', '芸芸众生', 'ftgccgch', '运营统筹', '招商经理', '品牌…', '背锅经理', '产品岗', '奋斗者', 'b', '微信运营', '互动装置，多媒体展厅', 'builders', 'me', '商业地产投资人', '铸币师', 'strategy', '手机电子产品销售', '创办人', '运输', '编导', '私营企业主', 'erp实施顾问', '政策顾问', '忘了', '业余评论员', '主编', '产品狗', '资深媒介策划', 'fae', '企业会员', '电子电路绘画员', '市场分析师', '战略研究', '工装室内外设计师', '金融分析师', '聯合創始人', '闲人', '原咨询顾问，现某厂员工.', '投资分析师助理', '供应部经理', '测试', '莫文蔚', '海外运营', '互联网行业', '待业', '监察大队', '风投', '程序员，it教育者', '行业经理', '设计行业内的非设计师', '高级java软件工程师', '投资分析', '体制内', '督导检核岗', '网络运营经理', 'marketer', '店长', '1', '企业主', '主人', 'mss', '管道工', '艺术教育', '33娘（手动滑稽）', '战略管理咨询师', '一般上班族', '小规模奋斗者', 'cxo', '眼镜人', '交互设计师', '码农，种植业',  ...

# %%
def temp_function(x,ceo_set=ceo_set,decision_level_set=decision_level_set,manager_set=manager_set,
    public_institution_set=public_institution_set,staff_set=staff_set,student_set=student_set,other_set=other_set):
    #x = datetime.datetime.now().year - int(x.split("-")[0])
    y = 0
    if x in ceo_set:
        y = "企业创始人/CEO"
    elif x in decision_level_set:
        y = "企业业务决策层"
    elif x in manager_set:
        y = "企业一般管理人员"
    elif x in public_institution_set:
        y = "事业单位员工"
    elif x in staff_set:
        y = "企业普通员工"
    elif x in student_set:
        y = "高校学生"
    else:
        y = "其他（自由职业）"
    return y

# %%
#这里有bug已解决
df[1] = df[1].apply(lambda x : temp_function(x.lower()))

# %%
df[1].unique()
# Out:
# array(['企业业务决策层', '企业普通员工', '企业创始人/CEO', '企业一般管理人员', '其他（自由职业）', '高校学生',
#        '事业单位员工'], dtype=object)

# %%
df.columns = ["aid","position",*["c{}".format(v) for v in range(10)]]
df
# Out:
#           aid   position      c0      c1      c2      c3      c4      c5  \
# 0           1    企业业务决策层  380021  379528  380043  380126  379521  379529
# 1       10073     企业普通员工  349684  349389  349248  349729  347400  349431
# 2       10113  企业创始人/CEO  378020  378036  377965  377980  378047  378021
# 3       10140     企业普通员工  381349  381108  381299  381252  380842  381326
# 4      101966  企业创始人/CEO  381295  381108  381284  381313  381106  380842
# ...       ...        ...     ...     ...     ...     ...     ...     ...
# 13129   92106     企业普通员工  380768  380727  380481  375323  379814  380669
# 13130   93648     企业普通员工  381369  381411  381424  381338  381299  381425
# 13131   95954     企业普通员工  374274  373823  373982  373774  374270  374217
# 13132   97037  企业创始人/CEO  364501  373305  372948  373553  373574  373512
# 13133   98706   其他（自由职业）  363108  363154  363094  363024  363136  363088
#
#            c6      c7      c8      c9
# 0      379451  379526  378915  379489
# 1      349650  349540  349572  348987
# 2      377903  377873  378033  378025
# 3      379187  381311  381059  380919
# 4      381316  381279  381315  381310
# ...       ...     ...     ...     ...
# 13129  380484  379839  380482  381027
# 13130  381554  381393  381309  381280
# 13131  373884  374259  373955  374257
# 13132  373551  373497  373480  373603
# 13133  358476  360535  363142  363102
#
# [13134 rows x 12 columns]

# %%
a_dict = {}
with open("/mnt/d/zourui/predict_user_attribute20201214/user_attribute20201231/user_profile/title_tokenize.jsonl") as f:
    for line in f:
        temp_dict = json.loads(line.strip())
        aid = temp_dict["aid"]
        a_dict[aid] = {}
        title_tokenize = temp_dict["title_tokenize"]
        a_dict[aid]["title_tokenize"] = title_tokenize

# %%
with open("/mnt/d/zourui/predict_user_attribute20201214/user_attribute20201231/user_profile/content_tokenize.jsonl") as f:
    for line in f:
        temp_dict = json.loads(line.strip())
        aid = temp_dict["aid"]
        if not aid in a_dict:
            print(aid)
            continue
        content_tokenize = temp_dict["content_tokenize"][:512]
        a_dict[aid]["content_tokenize"] = content_tokenize

# %%
df.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a2ad340c7413> in <module>()
# ----> 1 df.head(50)
#
# NameError: name 'df' is not defined

# %%
text_list = []
y_list = []
for index in df.index:
    y = df.loc[index,"position"]
    temp_text_list = []
    for i in range(10):
        c_text_list = []
        c = "c{}".format(i)
        aid = str(df.loc[index,c]).strip()
        if aid:
            if aid in a_dict:
                c_text_list = [*a_dict[aid]["title_tokenize"],"<PADDING>",*a_dict[aid]["content_tokenize"][:512]]
            else:
                print("aid不存在",index,c,aid)
        else:
            print(index)
        temp_text_list.append(c_text_list)     
    text_list.append(temp_text_list)
    y_list.append(y)
# Out:
# aid不存在 156 c3 130
# aid不存在 386 c3 130
# aid不存在 563 c8 161
# aid不存在 662 c3 130
# aid不存在 675 c3 130
# aid不存在 720 c8 142
# aid不存在 906 c2 161
# aid不存在 1229 c0 169
# aid不存在 1231 c6 154
# aid不存在 1639 c4 130
# aid不存在 1684 c6 134
# aid不存在 1935 c1 108
# aid不存在 3234 c2 130
# aid不存在 3647 c8 96
# aid不存在 3870 c5 130
# aid不存在 4503 c6 130
# aid不存在 5290 c8 126
# aid不存在 5308 c3 130
# aid不存在 5806 c5 130
# aid不存在 5933 c2 213
# aid不存在 5969 c5 130
# aid不存在 6370 c1 130
# aid不存在 6410 c7 134
# aid不存在 8428 c9 96
# aid不存在 8801 c2 161
# aid不存在 9226 c1 130
# aid不存在 11043 c5 154
# aid不存在 11634 c2 184
# aid不存在 11906 c9 142
# aid不存在 12117 c3 130

# %%
with open("/home/zourui/data/predict_user_attribute20200911/raw_data/user_profile/position/最终数据集tokenize8.jsonl","w") as f:
    for tag,content_tokenize in zip(y_list,text_list):
        f.write(json.dumps({"tag":tag,"all_content_tokenize":content_tokenize},ensure_ascii=False) + "\n")

# %%
import json
import os
import re
import collections
import numpy as np
import pandas as pd
import tensorflow as tf
import LAC
import happybase
import joblib

class Position_data_deal(object):
    
    def position_data_output(self,data_input_path,title_tokenize_path,content_tokenize_path,position_output_data_path):
        df_list = []
        with open(data_input_path) as f:
            for line in f:
                df_list.append(line.strip().split('\001'))
        df = pd.DataFrame(df_list)

        all_set = set([v.lower() for v in df[1]])
        ceo_set = set()
        ceo_pattern = re.compile('|'.join(map(re.escape, ["董事长","总裁","ceo","董事","合伙人","总经理","副总经理","老板"])),flags=re.IGNORECASE)
        #企业业务决策层
        decision_level_set = set()
        decision_level_pattern = re.compile('|'.join(map(re.escape, ['cio', 'cfo', 'coo', 'cto', 'cko', 'cpo', 'cgo', 'cmo', 'cso',"首席","行长","投资经理"])),flags=re.IGNORECASE)
        #企业一般管理人员
        manager_set = set()
        manager_pattern = re.compile('|'.join(map(re.escape, ["总监","主管","总助","负责人","中层干部"])),flags=re.IGNORECASE)
        # 事业单位员工
        public_institution_set = set()
        public_institution_pattern = re.compile('|'.join(map(re.escape, ["公务员","主任","教务","老师","教师","列车","政府","常委","教師","人民公仆","院长","医","驻华大使"])),flags=re.IGNORECASE)
        # 高校学生
        student_set = set()
        student_pattern = re.compile('|'.join(map(re.escape, ["二战","大专","高三","大四","大一","大二","大一","学生","研究生","博士","大学","应届生","本科","硕士","博士"])),flags=re.IGNORECASE)
        # 其他（自由职业）
        other_set = set()
        other_pattern = re.compile('|'.join(map(re.escape, ["自由","啥都干","流民","浪人"])),flags=re.IGNORECASE)
        #企业普通员工
        staff_set = set()
        staff_pattern =  re.compile('|'.join(map(re.escape, ["工程师","民工","分析师","设计师","苦力","编程","员工","工人","架构师",
           "清洁","经理助理","客户经理","项目经理","从业者","规划师","部经理","公务员","销售经理"])),flags=re.IGNORECASE)
        for v in all_set:
            if list(re.finditer(ceo_pattern,v)):
                ceo_set.add(v)
            elif list(re.finditer(decision_level_pattern,v)):
                decision_level_set.add(v)
            elif list(re.finditer(manager_pattern,v)):
                manager_set.add(v)
            elif list(re.finditer(public_institution_pattern,v)):
                public_institution_set.add(v)
            elif list(re.finditer(student_pattern,v)):
                student_set.add(v)
            elif list(re.finditer(staff_pattern,v)):
                staff_set.add(v)
            else:
                if list(re.finditer(other_pattern,v)) or len(v) > 10:
                    other_set.add(v)
                else:
                    staff_set.add(v)
        def temp_function(x,ceo_set=ceo_set,decision_level_set=decision_level_set,manager_set=manager_set,
        public_institution_set=public_institution_set,staff_set=staff_set,student_set=student_set,other_set=other_set):
        #x = datetime.datetime.now().year - int(x.split("-")[0])
            y = 0
            if x in ceo_set:
                y = "企业创始人/CEO"
            elif x in decision_level_set:
                y = "企业业务决策层"
            elif x in manager_set:
                y = "企业一般管理人员"
            elif x in public_institution_set:
                y = "事业单位员工"
            elif x in staff_set:
                y = "企业普通员工"
            elif x in student_set:
                y = "高校学生"
            else:
                y = "其他（自由职业）"
            return y
        df[1] = df[1].apply(lambda x : temp_function(x.lower()))
        df.columns = ["aid","position",*["c{}".format(v) for v in range(10)]]
        a_dict = {}
        with open(title_tokenize_path) as f:
            for line in f:
                temp_dict = json.loads(line.strip())
                aid = temp_dict["aid"]
                a_dict[aid] = {}
                title_tokenize = temp_dict["title_tokenize"]
                a_dict[aid]["title_tokenize"] = title_tokenize
        with open(content_tokenize_path) as f:
            for line in f:
                temp_dict = json.loads(line.strip())
                aid = temp_dict["aid"]
                if not aid in a_dict:
                    print(aid)
                    continue
                content_tokenize = temp_dict["content_tokenize"][:512]
                a_dict[aid]["content_tokenize"] = content_tokenize
        text_list = []
        y_list = []
        for index in df.index:
            y = df.loc[index,"position"]
            temp_text_list = []
            for i in range(10):
                c_text_list = []
                c = "c{}".format(i)
                aid = str(df.loc[index,c]).strip()
                if aid:
                    if aid in a_dict:
                        c_text_list = [*a_dict[aid]["title_tokenize"],"<PADDING>",*a_dict[aid]["content_tokenize"][:512]]
                    else:
                        print("aid不存在",index,c,aid)
                else:
                    print(index)
                temp_text_list.append(c_text_list)     
            text_list.append(temp_text_list)
            y_list.append(y)
        with open(position_output_data_path,"w") as f:
            for tag,content_tokenize in zip(y_list,text_list):
                f.write(json.dumps({"tag":tag,"all_content_tokenize":content_tokenize},ensure_ascii=False) + "\n")

# %%
data_input_path = "/mnt/d/zourui/predict_user_attribute20201214/user_attribute20201231/user_profile/position_data"
title_tokenize_path = "/mnt/d/zourui/predict_user_attribute20201214/user_attribute20201231/user_profile/title_tokenize.jsonl"
content_tokenize_path = "/mnt/d/zourui/predict_user_attribute20201214/user_attribute20201231/user_profile/content_tokenize.jsonl"
position_output_data_path = "/home/zourui/data/predict_user_attribute20200911/raw_data/user_profile/position/最终数据集tokenize8.jsonl"
position = Position_data_deal()
position.position_data_output(data_input_path,title_tokenize_path,content_tokenize_path,position_output_data_path)
# Out:
# aid不存在 156 c3 130
# aid不存在 386 c3 130
# aid不存在 563 c8 161
# aid不存在 662 c3 130
# aid不存在 675 c3 130
# aid不存在 720 c8 142
# aid不存在 906 c2 161
# aid不存在 1229 c0 169
# aid不存在 1231 c6 154
# aid不存在 1639 c4 130
# aid不存在 1684 c6 134
# aid不存在 1935 c1 108
# aid不存在 3234 c2 130
# aid不存在 3647 c8 96
# aid不存在 3870 c5 130
# aid不存在 4503 c6 130
# aid不存在 5290 c8 126
# aid不存在 5308 c3 130
# aid不存在 5806 c5 130
# aid不存在 5933 c2 213
# aid不存在 5969 c5 130
# aid不存在 6370 c1 130
# aid不存在 6410 c7 134
# aid不存在 8428 c9 96
# aid不存在 8801 c2 161
# aid不存在 9226 c1 130
# aid不存在 11043 c5 154
# aid不存在 11634 c2 184
# aid不存在 11906 c9 142
# aid不存在 12117 c3 130
